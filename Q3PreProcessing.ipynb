# %%
import pandas as pd
import numpy as np
from elasticsearch import Elasticsearch
import pickle
pd.options.mode.chained_assignment = None

# %% [markdown]
# #**Tf-Idf**

# %%
def computeTfIdf(atlas):
    data = {(i,j):atlas[i][j] for i in atlas.keys() for j in atlas[i].keys()}

    df = pd.DataFrame.from_dict(data, orient='index').sort_index()
    
    df["tf-idf"] = np.multiply(df["term_freq"], np.log( 9125 / df["doc_freq"]))

    df.index.names = ["movieId", "word"]
    
    tfidf = df.reset_index()
    tfidf.drop(["term_freq","doc_freq"],axis=1, inplace=True)
    tfidf.movieId = tfidf.movieId.astype("int64")
    tfidf["tf-idf"] = tfidf["tf-idf"].astype("float32")

    return tfidf

# %%
def Tf_Idf():
    ''' This function returns atlas_tfidf which has all movieId 
    and corresponding tfidf with their words ''' 
    # Dictionary with (es_id : movieId) pairs, where es_id is the _id from Elasticsearch
    ids = dict()
    #atlas is a dict with keys = movieId and values = { words : { 'doc_freq' : doc_freq , 'term_freq' : term_freq} }
    atlas = dict()
    # and word_params_dict = { words : { 'doc_freq' : doc_freq , 'term_freq' : term_freq} }
    word_params_dict = dict()

    res = es.search(index="movies", body={"query": {"match_all":{} }}, size = 10000)
    total_hits = res['hits']['total']['value']
    #here I create a dictionary with key-value pairs = (_id, movieId), where _id is from Elasticsearch
    for hit in range(total_hits):
        movieId = res['hits']['hits'][hit]['_source']['movieId']
        es_id = res['hits']['hits'][hit]['_id']
        ids[es_id] = movieId

    # every doc is a distinct movie. Thus, it has it's own _id from Elasticsearch
    # Out of every doc I need to get term_freq and doc_freq
    for movie in es.mtermvectors(index="movies",body=dict(ids=list(ids.keys()),parameters=dict(term_statistics=True,field_statistics=True,fields=["title"])))['docs']:                                                                                                                                                            
        title = movie['term_vectors'] 
        #get the movieId of the movie we are currently at
        movieId = ids.get( movie['_id'], None ) 
        #get the words in the title of the movie we are curently at
        words = title['title']['terms'].keys()
        # for each word get the parameters and save them on a dictionary
        for word in words:
            #for each word get the term and document frequency
            term_freq = title['title']['terms'][word]['term_freq']
            doc_freq = title['title']['terms'][word]['doc_freq']
            word_params_dict[word] = {'term_freq': term_freq, 'doc_freq' : doc_freq}
        # save said dictionary on the correct key of the atlas dictionary
        atlas[movieId] = word_params_dict
        #reset the dictionary
        word_params_dict = dict()
    atlas_tfidf = computeTfIdf(atlas)
    return atlas_tfidf

# %%
def createDF(movies_dummy_genre,tfidf_df,movie_rating_df_user):
  train_data = dict()
  pred_data = dict()

  tfidf_df_piv = tfidf_df.pivot(index='movieId', columns='word', values='tf-idf')
  tfidf_df_piv = tfidf_df_piv.astype(np.float16)

  mean_of_wrds = tfidf_df_piv.mean()

  tfidf_df_piv_NaN = tfidf_df_piv.fillna(mean_of_wrds)
  tfidf_df_piv_NaN = tfidf_df_piv_NaN.merge(movies_dummy_genre, on='movieId', how='left')

  for userId in list(movie_rating_df_user['userId'].unique()):
    print("\ncurrently on user : ", userId)
    user_data = tfidf_df_piv_NaN.merge(movie_rating_df_user[movie_rating_df_user['userId'] == userId],on='movieId', how = 'outer')

    user_pred_data = user_data[user_data['rating'].isnull()]
    user_pred_data.drop('userId',axis=1,inplace=True)

    user_train_data = user_data[~user_data['rating'].isnull()]
    user_train_data.drop('userId',axis=1,inplace=True)

    user_train_data.set_index('movieId', inplace=True)
    user_pred_data.set_index('movieId', inplace=True)
        
    pickle.dump(user_train_data, open("./Data/train/user_{}_train_data.p".format(userId), "wb"))
    pickle.dump(user_pred_data, open("./Data/predi/user_{}_pred_data.p".format(userId), "wb"))
  return

# %%
es = Elasticsearch()
print('\nPlease wait .....\n')
rating_df = pd.read_csv('./data/ratings.csv')  
movies_df = pd.read_csv('./data/movies.csv')
#one hot encoding movie genres
temp = movies_df['genres'].str.get_dummies()
temp.columns = ['Genre_' + str(col) for col in temp.columns ]
# movies_dummy_genre has dummy variables for all genres and also has movieId, title
movies_dummy_genre = movies_df.merge(temp, left_index=True, right_index=True)
movies_dummy_genre.drop(['title','genres'],axis=1,inplace=True)
tfidf_df = Tf_Idf()


movie_rating_df_user = rating_df[['userId','movieId','rating']]
# At this point I have all the info per movie I need so let's create the training dataframe per user
createDF(movies_dummy_genre, tfidf_df, movie_rating_df_user)
# Out:
# Please wait .....
#
#
# currently on user :  1
#
# currently on user :  2
#
# currently on user :  3
#
# currently on user :  4
#
# currently on user :  5
#
# currently on user :  6
#
# currently on user :  7
#
# currently on user :  8
#
# currently on user :  9
#
# currently on user :  10
#
# currently on user :  11
#
# currently on user :  12
#
# currently on user :  13
#
# currently on user :  14
#
# currently on user :  15
#
# currently on user :  16
#
# currently on user :  17
#
# currently on user :  18
#
# currently on user :  19
#
# currently on user :  20
#
# currently on user :  21
#
# currently on user :  22
#
# currently on user :  23
#
# currently on user :  24
#
# currently on user :  25
#
# currently on user :  26
#
# currently on user :  27
#
# currently on user :  28
#
# currently on user :  29
#
# currently on user :  30
#
# currently on user :  31
#
# currently on user :  32
#
# currently on user :  33
#
# currently on user :  34
#
# currently on user :  35
#
# currently on user :  36
#
# currently on user :  37
#
# currently on user :  38
#
# currently on user :  39
#
# currently on user :  40
#
# currently on user :  41
#
# currently on user :  42
#
# currently on user :  43
#
# currently on user :  44
#
# currently on user :  45
#
# currently on user :  46
#
# currently on user :  47
#
# currently on user :  48
#
# currently on user :  49
#
# currently on user :  50
#
# currently on user :  51
#
# currently on user :  52
#
# currently on user :  53
#
# currently on user :  54
#
# currently on user :  55
#
# currently on user :  56
#
# currently on user :  57
#
# currently on user :  58
#
# currently on user :  59
#
# currently on user :  60
#
# currently on user :  61
#
# currently on user :  62
#
# currently on user :  63
#
# currently on user :  64
#
# currently on user :  65
#
# currently on user :  66
#
# currently on user :  67
#
# currently on user :  68
#
# currently on user :  69
#
# currently on user :  70
#
# currently on user :  71
#
# currently on user :  72
#
# currently on user :  73
#
# currently on user :  74
#
# currently on user :  75
#
# currently on user :  76
#
# currently on user :  77
#
# currently on user :  78
#
# currently on user :  79
#
# currently on user :  80
#
# currently on user :  81
#
# currently on user :  82
#
# currently on user :  83
#
# currently on user :  84
#
# currently on user :  85
#
# currently on user :  86
#
# currently on user :  87
#
# currently on user :  88
#
# currently on user :  89
#
# currently on user :  90
#
# currently on user :  91
#
# currently on user :  92
#
# currently on user :  93
#
# currently on user :  94
#
# currently on user :  95
#
# currently on user :  96
#
# currently on user :  97
#
# currently on user :  98
#
# currently on user :  99
#
# currently on user :  100
#
# currently on user :  101
#
# currently on user :  102
#
# currently on user :  103
#
# currently on user :  104
#
# currently on user :  105
#
# currently on user :  106
#
# currently on user :  107
#
# currently on user :  108
#
# currently on user :  109
#
# currently on user :  110
#
# currently on user :  111
#
# currently on user :  112
#
# currently on user :  113
#
# currently on user :  114
#
# currently on user :  115
#
# currently on user :  116
#
# currently on user :  117
#
# currently on user :  118
#
# currently on user :  119
#
# currently on user :  120
#
# currently on user :  121
#
# currently on user :  122
#
# currently on user :  123
#
# currently on user :  124
#
# currently on user :  125
#
# currently on user :  126
#
# currently on user :  127
#
# currently on user :  128
#
# currently on user :  129
#
# currently on user :  130
#
# currently on user :  131
#
# currently on user :  132
#
# currently on user :  133
#
# currently on user :  134
#
# currently on user :  135
#
# currently on user :  136
#
# currently on user :  137
#
# currently on user :  138
#
# currently on user :  139
#
# currently on user :  140
#
# currently on user :  141
#
# currently on user :  142
#
# currently on user :  143
#
# currently on user :  144
#
# currently on user :  145
#
# currently on user :  146
#
# currently on user :  147
#
# currently on user :  148
#
# currently on user :  149
#
# currently on user :  150
#
# currently on user :  151
#
# currently on user :  152
#
# currently on user :  153
#
# currently on user :  154
#
# currently on user :  155
#
# currently on user :  156
#
# currently on user :  157
#
# currently on user :  158
#
# currently on user :  159
#
# currently on user :  160
#
# currently on user :  161
#
# currently on user :  162
#
# currently on user :  163
#
# currently on user :  164
#
# currently on user :  165
#
# currently on user :  166
#
# currently on user :  167
#
# currently on user :  168
#
# currently on user :  169
#
# currently on user :  170
#
# currently on user :  171
#
# currently on user :  172
#
# currently on user :  173
#
# currently on user :  174
#
# currently on user :  175
#
# currently on user :  176
#
# currently on user :  177
#
# currently on user :  178
#
# currently on user :  179
#
# currently on user :  180
#
# currently on user :  181
#
# currently on user :  182
#
# currently on user :  183
#
# currently on user :  184
#
# currently on user :  185
#
# currently on user :  186
#
# currently on user :  187
#
# currently on user :  188
#
# currently on user :  189
#
# currently on user :  190
#
# currently on user :  191
#
# currently on user :  192
#
# currently on user :  193
#
# currently on user :  194
#
# currently on user :  195
#
# currently on user :  196
#
# currently on user :  197
#
# currently on user :  198
#
# currently on user :  199
#
# currently on user :  200
#
# currently on user :  201
#
# currently on user :  202
#
# currently on user :  203
#
# currently on user :  204
#
# currently on user :  205
#
# currently on user :  206
#
# currently on user :  207
#
# currently on user :  208
#
# currently on user :  209
#
# currently on user :  210
#
# currently on user :  211
#
# currently on user :  212
#
# currently on user :  213
#
# currently on user :  214
#
# currently on user :  215
#
# currently on user :  216
#
# currently on user :  217
#
# currently on user :  218
#
# currently on user :  219
#
# currently on user :  220
#
# currently on user :  221
#
# currently on user :  222
#
# currently on user :  223
#
# currently on user :  224
#
# currently on user :  225
#
# currently on user :  226
#
# currently on user :  227
#
# currently on user :  228
#
# currently on user :  229
#
# currently on user :  230
#
# currently on user :  231
#
# currently on user :  232
#
# currently on user :  233
#
# currently on user :  234
#
# currently on user :  235
#
# currently on user :  236
#
# currently on user :  237
#
# currently on user :  238
#
# currently on user :  239
#
# currently on user :  240
#
# currently on user :  241
#
# currently on user :  242
#
# currently on user :  243
#
# currently on user :  244
#
# currently on user :  245
#
# currently on user :  246
#
# currently on user :  247
#
# currently on user :  248
#
# currently on user :  249
#
# currently on user :  250
#
# currently on user :  251
#
# currently on user :  252
#
# currently on user :  253
#
# currently on user :  254
#
# currently on user :  255
#
# currently on user :  256
#
# currently on user :  257
#
# currently on user :  258
#
# currently on user :  259
#
# currently on user :  260
#
# currently on user :  261
#
# currently on user :  262
#
# currently on user :  263
#
# currently on user :  264
#
# currently on user :  265
#
# currently on user :  266
#
# currently on user :  267
#
# currently on user :  268
#
# currently on user :  269
#
# currently on user :  270
#
# currently on user :  271
#
# currently on user :  272
#
# currently on user :  273
#
# currently on user :  274
#
# currently on user :  275
#
# currently on user :  276
#
# currently on user :  277
#
# currently on user :  278
#
# currently on user :  279
#
# currently on user :  280
#
# currently on user :  281
#
# currently on user :  282
#
# currently on user :  283
#
# currently on user :  284
#
# currently on user :  285
#
# currently on user :  286
#
# currently on user :  287
#
# currently on user :  288
#
# currently on user :  289
#
# currently on user :  290
#
# currently on user :  291
#
# currently on user :  292
#
# currently on user :  293
#
# currently on user :  294
#
# currently on user :  295
#
# currently on user :  296
#
# currently on user :  297
#
# currently on user :  298
#
# currently on user :  299
#
# currently on user :  300
#
# currently on user :  301
#
# currently on user :  302
#
# currently on user :  303
#
# currently on user :  304
#
# currently on user :  305
#
# currently on user :  306
#
# currently on user :  307
#
# currently on user :  308
#
# currently on user :  309
#
# currently on user :  310
#
# currently on user :  311
#
# currently on user :  312
#
# currently on user :  313
#
# currently on user :  314
#
# currently on user :  315
#
# currently on user :  316
#
# currently on user :  317
#
# currently on user :  318
#
# currently on user :  319
# currently on user :  320
#
# currently on user :  321
#
# currently on user :  322
#
# currently on user :  323
#
# currently on user :  324
#
# currently on user :  325
#
# currently on user :  326
#
# currently on user :  327
#
# currently on user :  328
#
# currently on user :  329
#
# currently on user :  330
#
# currently on user :  331
#
# currently on user :  332
#
# currently on user :  333
#
# currently on user :  334
#
# currently on user :  335
#
# currently on user :  336
#
# currently on user :  337
#
# currently on user :  338
#
# currently on user :  339
#
# currently on user :  340
#
# currently on user :  341
#
# currently on user :  342
#
# currently on user :  343
#
# currently on user :  344
#
# currently on user :  345
#
# currently on user :  346
#
# currently on user :  347
#
# currently on user :  348
#
# currently on user :  349
#
# currently on user :  350
#
# currently on user :  351
#
# currently on user :  352
#
# currently on user :  353
#
# currently on user :  354
#
# currently on user :  355
#
# currently on user :  356
#
# currently on user :  357
#
# currently on user :  358
#
# currently on user :  359
#
# currently on user :  360
#
# currently on user :  361
#
# currently on user :  362
#
# currently on user :  363
#
# currently on user :  364
#
# currently on user :  365
#
# currently on user :  366
#
# currently on user :  367
#
# currently on user :  368
#
# currently on user :  369
#
# currently on user :  370
#
# currently on user :  371
#
# currently on user :  372
#
# currently on user :  373
#
# currently on user :  374
#
# currently on user :  375
#
# currently on user :  376
#
# currently on user :  377
#
# currently on user :  378
#
# currently on user :  379
#
# currently on user :  380
#
# currently on user :  381
#
# currently on user :  382
#
# currently on user :  383
#
# currently on user :  384
#
# currently on user :  385
#
# currently on user :  386
#
# currently on user :  387
#
# currently on user :  388
#
# currently on user :  389
#
# currently on user :  390
#
# currently on user :  391
#
# currently on user :  392
#
# currently on user :  393
#
# currently on user :  394
#
# currently on user :  395
#
# currently on user :  396
#
# currently on user :  397
#
# currently on user :  398
#
# currently on user :  399
#
# currently on user :  400
#
# currently on user :  401
#
# currently on user :  402
#
# currently on user :  403
#
# currently on user :  404
#
# currently on user :  405
#
# currently on user :  406
#
# currently on user :  407
#
# currently on user :  408
#
# currently on user :  409
#
# currently on user :  410
#
# currently on user :  411
#
# currently on user :  412
#
# currently on user :  413
#
# currently on user :  414
#
# currently on user :  415
#
# currently on user :  416
#
# currently on user :  417
#
# currently on user :  418
#
# currently on user :  419
#
# currently on user :  420
#
# currently on user :  421
#
# currently on user :  422
#
# currently on user :  423
#
# currently on user :  424
#
# currently on user :  425
#
# currently on user :  426
#
# currently on user :  427
#
# currently on user :  428
#
# currently on user :  429
#
# currently on user :  430
#
# currently on user :  431
#
# currently on user :  432
#
# currently on user :  433
#
# currently on user :  434
#
# currently on user :  435
#
# currently on user :  436
#
# currently on user :  437
#
# currently on user :  438
#
# currently on user :  439
#
# currently on user :  440
#
# currently on user :  441
#
# currently on user :  442
#
# currently on user :  443
#
# currently on user :  444
#
# currently on user :  445
#
# currently on user :  446
#
# currently on user :  447
#
# currently on user :  448
#
# currently on user :  449
#
# currently on user :  450
#
# currently on user :  451
#
# currently on user :  452
#
# currently on user :  453
#
# currently on user :  454
#
# currently on user :  455
#
# currently on user :  456
#
# currently on user :  457
#
# currently on user :  458
#
# currently on user :  459
#
# currently on user :  460
#
# currently on user :  461
#
# currently on user :  462
#
# currently on user :  463
#
# currently on user :  464
#
# currently on user :  465
#
# currently on user :  466
#
# currently on user :  467
#
# currently on user :  468
#
# currently on user :  469
#
# currently on user :  470
#
# currently on user :  471
#
# currently on user :  472
#
# currently on user :  473
#
# currently on user :  474
#
# currently on user :  475
#
# currently on user :  476
#
# currently on user :  477
#
# currently on user :  478
#
# currently on user :  479
#
# currently on user :  480
#
# currently on user :  481
#
# currently on user :  482
#
# currently on user :  483
#
# currently on user :  484
#
# currently on user :  485
#
# currently on user :  486
#
# currently on user :  487
#
# currently on user :  488
#
# currently on user :  489
#
# currently on user :  490
#
# currently on user :  491
#
# currently on user :  492
#
# currently on user :  493
#
# currently on user :  494
#
# currently on user :  495
#
# currently on user :  496
#
# currently on user :  497
#
# currently on user :  498
#
# currently on user :  499
#
# currently on user :  500
#
# currently on user :  501
#
# currently on user :  502
#
# currently on user :  503
#
# currently on user :  504
#
# currently on user :  505
#
# currently on user :  506
#
# currently on user :  507
#
# currently on user :  508
#
# currently on user :  509
#
# currently on user :  510
#
# currently on user :  511
#
# currently on user :  512
#
# currently on user :  513
#
# currently on user :  514
#
# currently on user :  515
#
# currently on user :  516
#
# currently on user :  517
#
# currently on user :  518
#
# currently on user :  519
#
# currently on user :  520
#
# currently on user :  521
#
# currently on user :  522
#
# currently on user :  523
#
# currently on user :  524
#
# currently on user :  525
#
# currently on user :  526
#
# currently on user :  527
#
# currently on user :  528
#
# currently on user :  529
#
# currently on user :  530
#
# currently on user :  531
#
# currently on user :  532
#
# currently on user :  533
#
# currently on user :  534
#
# currently on user :  535
#
# currently on user :  536
#
# currently on user :  537
#
# currently on user :  538
#
# currently on user :  539
#
# currently on user :  540
#
# currently on user :  541
#
# currently on user :  542
#
# currently on user :  543
#
# currently on user :  544
#
# currently on user :  545
#
# currently on user :  546
#
# currently on user :  547
#
# currently on user :  548
#
# currently on user :  549
#
# currently on user :  550
#
# currently on user :  551
#
# currently on user :  552
#
# currently on user :  553
#
# currently on user :  554
#
# currently on user :  555
#
# currently on user :  556
#
# currently on user :  557
#
# currently on user :  558
#
# currently on user :  559
#
# currently on user :  560
#
# currently on user :  561
#
# currently on user :  562
#
# currently on user :  563
#
# currently on user :  564
#
# currently on user :  565
#
# currently on user :  566
#
# currently on user :  567
#
# currently on user :  568
#
# currently on user :  569
#
# currently on user :  570
#
# currently on user :  571
#
# currently on user :  572
#
# currently on user :  573
#
# currently on user :  574
#
# currently on user :  575
#
# currently on user :  576
#
# currently on user :  577
#
# currently on user :  578
#
# currently on user :  579
#
# currently on user :  580
#
# currently on user :  581
#
# currently on user :  582
#
# currently on user :  583
#
# currently on user :  584
#
# currently on user :  585
#
# currently on user :  586
#
# currently on user :  587
#
# currently on user :  588
#
# currently on user :  589
#
# currently on user :  590
#
# currently on user :  591
#
# currently on user :  592
#
# currently on user :  593
#
# currently on user :  594
#
# currently on user :  595
#
# currently on user :  596
#
# currently on user :  597
#
# currently on user :  598
#
# currently on user :  599
#
# currently on user :  600
#
# currently on user :  601
#
# currently on user :  602
#
# currently on user :  603
#
# currently on user :  604
#
# currently on user :  605
#
# currently on user :  606
#
# currently on user :  607
#
# currently on user :  608
#
# currently on user :  609
#
# currently on user :  610
#
# currently on user :  611
#
# currently on user :  612
#
# currently on user :  613
#
# currently on user :  614
#
# currently on user :  615
#
# currently on user :  616
#
# currently on user :  617
#
# currently on user :  618
#
# currently on user :  619
#
# currently on user :  620
#
# currently on user :  621
#
# currently on user :  622
#
# currently on user :  623
#
# currently on user :  624
#
# currently on user :  625
#
# currently on user :  626
#
# currently on user :  627
#
# currently on user :  628
#
# currently on user :  629
#
# currently on user :  630
#
# currently on user :  631
#
# currently on user :  632
#
# currently on user :  633
#
# currently on user :  634
#
# currently on user :  635
# currently on user :  636
#
# currently on user :  637
#
# currently on user :  638
#
# currently on user :  639
#
# currently on user :  640
#
# currently on user :  641
#
# currently on user :  642
#
# currently on user :  643
#
# currently on user :  644
#
# currently on user :  645
#
# currently on user :  646
#
# currently on user :  647
#
# currently on user :  648
#
# currently on user :  649
#
# currently on user :  650
#
# currently on user :  651
#
# currently on user :  652
#
# currently on user :  653
#
# currently on user :  654
#
# currently on user :  655
#
# currently on user :  656
#
# currently on user :  657
#
# currently on user :  658
#
# currently on user :  659
#
# currently on user :  660
#
# currently on user :  661
#
# currently on user :  662
#
# currently on user :  663
#
# currently on user :  664
#
# currently on user :  665
#
# currently on user :  666
#
# currently on user :  667
#
# currently on user :  668
#
# currently on user :  669
#
# currently on user :  670
#
# currently on user :  671
